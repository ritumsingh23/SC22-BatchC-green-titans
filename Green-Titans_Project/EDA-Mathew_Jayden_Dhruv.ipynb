# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
banknotes_dataset = pd.read_csv("banknotes.csv")

# %%
notesdimension_dataset = pd.read_csv("banknotes.csv")

# %%
banknotes_dataset
# Out:
#      conterfeit  Length   Left  Right  Bottom   Top  Diagonal
# 0             0   214.8  131.0  131.1     9.0   9.7     141.0
# 1             0   214.6  129.7  129.7     8.1   9.5     141.7
# 2             0   214.8  129.7  129.7     8.7   9.6     142.2
# 3             0   214.8  129.7  129.6     7.5  10.4     142.0
# 4             0   215.0  129.6  129.7    10.4   7.7     141.8
# ..          ...     ...    ...    ...     ...   ...       ...
# 195           1   215.0  130.4  130.3     9.9  12.1     139.6
# 196           1   215.1  130.3  129.9    10.3  11.5     139.7
# 197           1   214.8  130.3  130.4    10.6  11.1     140.0
# 198           1   214.7  130.7  130.8    11.2  11.2     139.4
# 199           1   214.3  129.9  129.9    10.2  11.5     139.6
#
# [200 rows x 7 columns]

# %%
banknotes_dataset["Length"].hist()
# Out:
# <AxesSubplot:>

# %%
#This can help us becuase now we know what the average Length of the swiss banknote

# %%
banknotes_dataset.plot.scatter(x = 'Left', y = 'Right')
# Out:
# <AxesSubplot:xlabel='Left', ylabel='Right'>

# %%
banknotes_dataset.plot.scatter(x = 'Length', y = 'Diagonal')
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Diagonal'>

# %%
banknotes_dataset["Length"].plot.pie(subplots=True, figsize=(15,15))
# Out:
# array([<AxesSubplot:ylabel='Length'>], dtype=object)

# %%
#

# %%
banknotes_dataset["Diagonal"].hist()
# Out:
# <AxesSubplot:>

# %%
#This graph shows us where most of the swiss banknotes have a specific diagonal length

# %%
        my_list = []
for column in notesdimension_dataset.itertuples():
#     print(colummn)
    temp_list = []
    if column[2] == 138:
        temp_list.append(row[1])
        temp_list.append(row[2])
        temp_list.append(row[3])
        temp_list.append(row[4])
        temp_list.append(row[5])
        temp_list.append(row[6])
        temp_list.append(row[7])
        temp_list.append('Length matches 20 franc note')
    else:
        temp_list.append(row[1])
        temp_list.append(row[2])
        temp_list.append(row[3])
        temp_list.append(row[4])
        temp_list.append(row[5])
        temp_list.append(row[6])
        temp_list.append(row[7])
        temp_list.append('Length does not match 20 france note')
        
    my_list.append(temp_list)
    
    
df = pd.DataFrame(my_list, columns = ['counterfeit', 'length', 'left', 'right', 'bottom', 'top', 'diagonal', '20 franc length'])
df.head()
# Out:
#    counterfeit  length   left  right  bottom   top  diagonal  \
# 0            1   214.3  129.9  129.9    10.2  11.5     139.6
# 1            1   214.3  129.9  129.9    10.2  11.5     139.6
# 2            1   214.3  129.9  129.9    10.2  11.5     139.6
# 3            1   214.3  129.9  129.9    10.2  11.5     139.6
# 4            1   214.3  129.9  129.9    10.2  11.5     139.6
#
#                         20 franc length
# 0  Length does not match 20 france note
# 1  Length does not match 20 france note
# 2  Length does not match 20 france note
# 3  Length does not match 20 france note
# 4  Length does not match 20 france note

# %%
my_list = []
for row in notesdimension_dataset.itertuples():
#     print(row)
    temp_list = []
    if row[2] < 215:
        temp_list.append(row[1])
        temp_list.append(row[2])
        temp_list.append(row[3])
        temp_list.append(row[4])
        temp_list.append(row[5])
        temp_list.append(row[6])
        temp_list.append(row[7])
        temp_list.append('less than 215')
    else:
        temp_list.append(row[1])
        temp_list.append(row[2])
        temp_list.append(row[3])
        temp_list.append(row[4])
        temp_list.append(row[5])
        temp_list.append(row[6])
        temp_list.append(row[7])
        temp_list.append('greater than 215')
        
    my_list.append(temp_list)
    
    
df = pd.DataFrame(my_list, columns = ['counterfiete', 'length', 'left', 'right', 'bottom', 'top', 'diagonal', 'lenth_category'])
df.head()
# Out:
#    counterfiete  length   left  right  bottom   top  diagonal  \
# 0             0   214.8  131.0  131.1     9.0   9.7     141.0
# 1             0   214.6  129.7  129.7     8.1   9.5     141.7
# 2             0   214.8  129.7  129.7     8.7   9.6     142.2
# 3             0   214.8  129.7  129.6     7.5  10.4     142.0
# 4             0   215.0  129.6  129.7    10.4   7.7     141.8
#
#      lenth_category
# 0     less than 215
# 1     less than 215
# 2     less than 215
# 3     less than 215
# 4  greater than 215
